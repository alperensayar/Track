# %% [markdown]
# <a href="https://colab.research.google.com/github/alperensayar/Track/blob/master/Untitled31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("country_vaccination_stats.csv")
df.head()
# Out:
#      country        date  daily_vaccinations   vaccines
# 0  Argentina  12/29/2020                 NaN  Sputnik V
# 1  Argentina  12/30/2020             15656.0  Sputnik V
# 2  Argentina  12/31/2020             15656.0  Sputnik V
# 3  Argentina    1/1/2021             11070.0  Sputnik V
# 4  Argentina    1/2/2021              8776.0  Sputnik V

# %%
df.describe().T
# Out:
#                      count          mean  ...       75%        max
# daily_vaccinations  1442.0  43349.586685  ...  27979.75  1126251.0
#
# [1 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# country                0
# date                   0
# daily_vaccinations    60
# vaccines               0
# dtype: int64

# %%
"""
Code Implementation Task: Implement code to fill the missing data (impute) in daily_vaccinations column per country with the minimum daily vaccination number of relevant countries.  
Note: If a country does not have any valid vaccination number yet, fill it with “0” (zero). 
"""
# Out:
# '\nCode Implementation Task: Implement code to fill the missing data (impute) in daily_vaccinations column per country with the minimum daily vaccination number of relevant countries.  \nNote: If a country does not have any valid vaccination number yet, fill it with “0” (zero). \n'

# %%
bool_series = pd.isnull(df["daily_vaccinations"])  

df[bool_series]
# Out:
#                    country  ...                               vaccines
# 0                Argentina  ...                              Sputnik V
# 28                 Austria  ...                        Pfizer/BioNTech
# 48                 Bahrain  ...             Pfizer/BioNTech, Sinopharm
# 77                 Belgium  ...                        Pfizer/BioNTech
# 103                 Brazil  ...                                Sinovac
# 113               Bulgaria  ...               Moderna, Pfizer/BioNTech
# 141                 Canada  ...               Moderna, Pfizer/BioNTech
# 184                  Chile  ...                        Pfizer/BioNTech
# 217                  China  ...                          CNBG, Sinovac
# 254             Costa Rica  ...                        Pfizer/BioNTech
# 280                Croatia  ...                        Pfizer/BioNTech
# 307                 Cyprus  ...                        Pfizer/BioNTech
# 324                Czechia  ...               Moderna, Pfizer/BioNTech
# 354                Denmark  ...               Moderna, Pfizer/BioNTech
# 384                Ecuador  ...                        Pfizer/BioNTech
# 386                England  ...    Oxford/AstraZeneca, Pfizer/BioNTech
# 422                Estonia  ...                        Pfizer/BioNTech
# 451                Finland  ...                        Pfizer/BioNTech
# 477                 France  ...                        Pfizer/BioNTech
# 499                Germany  ...               Moderna, Pfizer/BioNTech
# 528              Gibraltar  ...                        Pfizer/BioNTech
# 543                 Greece  ...                        Pfizer/BioNTech
# 572                Hungary  ...                        Pfizer/BioNTech
# 600                Iceland  ...               Moderna, Pfizer/BioNTech
# 627                  India  ...                    Covaxin, Covishield
# 638              Indonesia  ...                                Sinovac
# 652                Ireland  ...                        Pfizer/BioNTech
# 677            Isle of Man  ...                        Pfizer/BioNTech
# 682                 Israel  ...               Moderna, Pfizer/BioNTech
# 720                  Italy  ...                        Pfizer/BioNTech
# 750                 Kuwait  ...                        Pfizer/BioNTech
# 751                 Latvia  ...                        Pfizer/BioNTech
# 780              Lithuania  ...               Moderna, Pfizer/BioNTech
# 812             Luxembourg  ...                        Pfizer/BioNTech
# 838                  Malta  ...                        Pfizer/BioNTech
# 866                 Mexico  ...                        Pfizer/BioNTech
# 899            Netherlands  ...               Moderna, Pfizer/BioNTech
# 916       Northern Ireland  ...    Oxford/AstraZeneca, Pfizer/BioNTech
# 959                 Norway  ...                        Pfizer/BioNTech
# 988                   Oman  ...                        Pfizer/BioNTech
# 1016                Panama  ...                        Pfizer/BioNTech
# 1022                Poland  ...                        Pfizer/BioNTech
# 1050              Portugal  ...                        Pfizer/BioNTech
# 1079               Romania  ...                        Pfizer/BioNTech
# 1108                Russia  ...                              Sputnik V
# 1138          Saudi Arabia  ...                        Pfizer/BioNTech
# 1150              Scotland  ...    Oxford/AstraZeneca, Pfizer/BioNTech
# 1193                Serbia  ...  Pfizer/BioNTech, Sinopharm, Sputnik V
# 1211            Seychelles  ...                              Sinopharm
# 1226             Singapore  ...                        Pfizer/BioNTech
# 1238              Slovakia  ...                        Pfizer/BioNTech
# 1256              Slovenia  ...                        Pfizer/BioNTech
# 1278                 Spain  ...               Moderna, Pfizer/BioNTech
# 1300                Sweden  ...                        Pfizer/BioNTech
# 1322           Switzerland  ...                        Pfizer/BioNTech
# 1352                Turkey  ...                                Sinovac
# 1365  United Arab Emirates  ...             Pfizer/BioNTech, Sinopharm
# 1386        United Kingdom  ...    Oxford/AstraZeneca, Pfizer/BioNTech
# 1422         United States  ...               Moderna, Pfizer/BioNTech
# 1459                 Wales  ...    Oxford/AstraZeneca, Pfizer/BioNTech
#
# [60 rows x 4 columns]

# %%
def min_target(variable):
    temp = df[df[variable].notnull()]
    temp = temp[[variable, 'country']].groupby(['country'])[[variable]].min().reset_index()
    return temp

# %%
temp=min_target("daily_vaccinations")

# %%
a=df[bool_series].index

# %%
for i in range(len(a)):
  if (df.loc[a[i]]["country"] in temp.values):
    df["daily_vaccinations"].fillna(temp[temp["country"]==df.loc[a[0]]["country"]]["daily_vaccinations"],inplace=True)
    
  else:
    df["daily_vaccinations"].fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# country               0
# date                  0
# daily_vaccinations    0
# vaccines              0
# dtype: int64
